# %%
import pandas as pd
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func, inspect
from flask import Flask, jsonify

# %%
aircanada_csv = "../Stock_vs_Covid19/AC.TO.csv"
aircanada_df = pd.read_csv(aircanada_csv)
aircanada_df.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 0  2019-01-02  25.490000  26.320000  25.209999  25.830000  25.830000
# 1  2019-01-03  25.860001  25.860001  24.750000  25.110001  25.110001
# 2  2019-01-04  25.330000  26.770000  25.280001  26.690001  26.690001
# 3  2019-01-07  26.629999  26.840000  26.309999  26.719999  26.719999
# 4  2019-01-08  26.780001  27.010000  26.100000  26.660000  26.660000
#
#       Volume
# 0   772542.0
# 1  1039727.0
# 2  1023931.0
# 3  1153533.0
# 4   973847.0

# %%
 # Create a filtered dataframe from specific columns
rest_cols = ["Date", "Open", "High", "Low", "Close", "Adj Close", "Volume"]
aircanada_transformed= aircanada_df[rest_cols].copy()

# Rename the column headers
aircanada_transformed = aircanada_transformed.rename(columns={"Adj Close": "Adj_Close"
                                                         })
# Adds a column for the tickers
aircanada_transformed.insert(7,column="Ticker", value= "AC.TO")

# This is to drop the Close column as it is not necessary.
del aircanada_transformed['Close']

aircanada_transformed.head()
# Out:
#          Date       Open       High        Low  Adj_Close     Volume Ticker
# 0  2019-01-02  25.490000  26.320000  25.209999  25.830000   772542.0  AC.TO
# 1  2019-01-03  25.860001  25.860001  24.750000  25.110001  1039727.0  AC.TO
# 2  2019-01-04  25.330000  26.770000  25.280001  26.690001  1023931.0  AC.TO
# 3  2019-01-07  26.629999  26.840000  26.309999  26.719999  1153533.0  AC.TO
# 4  2019-01-08  26.780001  27.010000  26.100000  26.660000   973847.0  AC.TO

# %%
engine = create_engine("postgres://hlcobfze:eHurapQ1bUcdbsXYcSR5cfsbN0Smigsu@suleiman.db.elephantsql.com:5432/hlcobfze", pool_size=10, max_overflow=20)
Base = automap_base()
Base.prepare(engine, reflect=True)
inspector = inspect(engine)
print(inspector.get_tables_names())
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2335         try:
# -> 2336             return fn()
#    2337         except dialect.dbapi.Error as e:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in unique_connection(self)
#     303         """
# --> 304         return _ConnectionFairy._checkout(self)
#     305
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     494     def checkout(cls, pool):
# --> 495         rec = pool._do_get()
#     496         try:
#
# ...

# %%
engine.table_names()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2335         try:
# -> 2336             return fn()
#    2337         except dialect.dbapi.Error as e:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     363         if not self._use_threadlocal:
# --> 364             return _ConnectionFairy._checkout(self)
#     365
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     494     def checkout(cls, pool):
# --> 495         rec = pool._do_get()
#     496         try:
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-9d2cbca546df> in <module>
#       1 engine = create_engine("postgres://hlcobfze:eHurapQ1bUcdbsXYcSR5cfsbN0Smigsu@suleiman.db.elephantsql.com:5432/hlcobfze", pool_size=10, max_overflow=20)
#       2 session = engine
# ----> 3 session.close()
#
# AttributeError: 'Engine' object has no attribute 'close'
